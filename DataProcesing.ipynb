# %%
# !pip install --upgrade xlrd # this worked for me
# !pip install openpyxl
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: xlrd in /usr/local/lib/python3.9/site-packages (2.0.1)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
import os
import urllib

# Brute data from different sources:
# https://ai-project-inflation.s3.amazonaws.com/
DOWNLOAD_ROOT = "https://ai-project-inflation.s3.amazonaws.com/"
INFLATION_PATH = os.path.join("datasets", "inflation")

def fetch_housing_data(file_name):
    inflation_url= DOWNLOAD_ROOT+file_name
    inflation_path=INFLATION_PATH
    if not os.path.isdir(inflation_path):
        os.makedirs(inflation_path)
    inflation_path_final = os.path.join(inflation_path, file_name)
    if not os.path.exists(inflation_path_final):
        urllib.request.urlretrieve(inflation_url, inflation_path_final)

def load_inflation_data(file_name):
    fetch_housing_data(file_name)
    return os.path.join(INFLATION_PATH,file_name)

# %%
import pandas as pd
import datetime
def truncate_date(date):
  ts = pd.to_datetime(str(date))
  return ts.strftime('%Y-%m')

def parsing_string_to_date_withdash(date):
  format = "%B-%Y"
  return truncate_date(datetime.datetime.strptime(date, format))

def parsing_string_to_date(date):
  format = "%B %Y"
  return truncate_date(datetime.datetime.strptime(date, format))

# %%
brent_crude_prices = pd.read_excel(load_inflation_data("Brent_crude_prices.xls"), sheet_name=1, header=2)
brent_crude_prices["Date"] = brent_crude_prices["Date"].apply(truncate_date)
brent_crude_prices.rename(columns={'Europe Brent Spot Price FOB (Dollars per Barrel)': 'Crude_prices'}, inplace=True)
brent_crude_prices.head()
# Out:
#       Date  Crude_prices
# 0  1987-05         18.58
# 1  1987-06         18.86
# 2  1987-07         19.86
# 3  1987-08         18.98
# 4  1987-09         18.31

# %%
prime_rate = pd.read_excel(load_inflation_data("Prime_Rate_History-WOWA.xlsx"))
prime_rate["Date"] = prime_rate["Date"].apply(parsing_string_to_date)
prime_rate.rename(columns={'Prime Rate': 'Prime_Rate'}, inplace=True)


prime_rate = prime_rate[["Date","Prime_Rate" ]]
prime_rate.head()
# Out:
#       Date  Prime_Rate
# 0  1935-01        5.50
# 1  1936-01        5.21
# 2  1937-01        5.00
# 3  1938-01        5.00
# 4  1939-01        5.00

# %%
bond_rate = pd.read_csv(load_inflation_data("StlouisfedCAD10yearbondrate.csv"))
bond_rate.rename(columns={'DATE': 'Date'}, inplace=True)
bond_rate.rename(columns={'IRLTLT01CAM156N': '10_year_bond'}, inplace=True)
bond_rate["Date"] = bond_rate["Date"].apply(truncate_date)
bond_rate.head()
# Out:
#       Date  10_year_bond
# 0  2000-01      6.491500
# 1  2000-02      6.338571
# 2  2000-03      6.028261
# 3  2000-04      5.924211
# 4  2000-05      6.215000

# %%
manufacturing_rate = pd.read_csv(load_inflation_data("Stlouisfeb_hourmanurate.csv"))
manufacturing_rate.rename(columns={'DATE': 'Date'}, inplace=True)
manufacturing_rate.rename(columns={'LCEAMN01CAM189S': 'manu_labor_rate'}, inplace=True)
manufacturing_rate["Date"] = manufacturing_rate["Date"].apply(truncate_date)
manufacturing_rate.head()
# Out:
#       Date  manu_labor_rate
# 0  2000-01            18.25
# 1  2000-02            18.33
# 2  2000-03            18.23
# 3  2000-04            18.27
# 4  2000-05            18.42

# %%
money_supply = pd.read_csv(load_inflation_data("Stlousisfed_Canadain_Money_supply.csv"))
money_supply.rename(columns={'DATE': 'Date'}, inplace=True)
money_supply.rename(columns={'MANMM101CAM189S': 'CAD_M1_MoneySupply'}, inplace=True)
money_supply["Date"] = money_supply["Date"].apply(truncate_date)
money_supply.head()
# Out:
#       Date  CAD_M1_MoneySupply
# 0  2000-01        2.166880e+11
# 1  2000-02        2.216730e+11
# 2  2000-03        2.250820e+11
# 3  2000-04        2.284850e+11
# 4  2000-05        2.281010e+11

# %%
fed_fx_rates = pd.read_csv(load_inflation_data("stlousisfedFXRates.csv"))
fed_fx_rates.rename(columns={'DATE': 'Date'}, inplace=True)
fed_fx_rates.rename(columns={'CCUSMA02CAM618N': 'USD_CAD_rate'}, inplace=True)
fed_fx_rates["Date"] = fed_fx_rates["Date"].apply(truncate_date)
fed_fx_rates.head()
# Out:
#       Date  USD_CAD_rate
# 0  2000-01      1.448226
# 1  2000-02      1.450341
# 2  2000-03      1.460354
# 3  2000-04      1.468305
# 4  2000-05      1.494781

# %%
inflation = pd.read_csv(load_inflation_data("1810025901-eng.csv"))
inflation["Date"] = inflation["Date"].apply(truncate_date)

inflation = inflation[["Date", "Inflation_Rate"]]
inflation.head()
# Out:
#       Date  Inflation_Rate
# 0  2000-01             1.5
# 1  2000-02             1.8
# 2  2000-03             1.8
# 3  2000-04             1.4
# 4  2000-05             1.6

# %%
tsx_data = pd.read_csv(load_inflation_data("TSX_data_for_20_years.csv"))
tsx_data["Date"] = tsx_data["Date"].apply(truncate_date)
tsx_data = tsx_data[["Date", "Close"]]
tsx_data.rename(columns={'Close': 'SNP_TSX_Close'}, inplace=True)
tsx_data.head()
# Out:
#       Date  SNP_TSX_Close
# 0  2000-01    8481.099609
# 1  2000-02    9129.000000
# 2  2000-03    9462.400391
# 3  2000-04    9347.599609
# 4  2000-05    9252.000000

# %%
dataList = [inflation, prime_rate, brent_crude_prices,bond_rate, manufacturing_rate, money_supply, fed_fx_rates, tsx_data]
data_merged = pd.DataFrame()
initialIteration = True
for single_data in dataList:
  if initialIteration:
    data_merged = single_data.copy()
    initialIteration = False
  else:
    data_merged= data_merged.merge(single_data, how='left')

# %%
data_merged = data_merged[:-3]
data_merged.to_csv('data_merged.csv', index = True)
data_merged.to_pickle("data_merged.pkl")
data_merged.shape
# Out:
# (270, 9)

# %%
data_merged.head()
# Out:
#       Date  Inflation_Rate  Prime_Rate  Crude_prices  10_year_bond  \
# 0  2000-01             1.5        6.50         25.51      6.491500
# 1  2000-02             1.8        6.75         27.78      6.338571
# 2  2000-03             1.8        7.00         27.49      6.028261
# 3  2000-04             1.4        7.00         22.76      5.924211
# 4  2000-05             1.6        7.50         27.74      6.215000
#
#    manu_labor_rate  CAD_M1_MoneySupply  USD_CAD_rate  SNP_TSX_Close
# 0            18.25        2.166880e+11      1.448226    8481.099609
# 1            18.33        2.216730e+11      1.450341    9129.000000
# 2            18.23        2.250820e+11      1.460354    9462.400391
# 3            18.27        2.284850e+11      1.468305    9347.599609
# 4            18.42        2.281010e+11      1.494781    9252.000000
